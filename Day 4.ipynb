# %%
num1=4
print(type(num1))
# Out:
# <class 'int'>

# %%
lists are data structure used to store data,can be changed,can be accessable

# %%
l1=['Badri','Vallur','Ram','Veer']
print(l1)
# Out:
# ['Badri', 'Vallur', 'Ram', 'Veer']

# %%
l1.append('varun')
print(l1)
# Out:
# ['Badri', 'Vallur', 'Ram', 'Veer', 'varun']

# %%
l1.insert(2,'irfan')
print(l1)
# Out:
# ['Badri', 'Vallur', 'irfan', 'Ram', 'Veer', 'varun']

# %%
l1[2]='dinesh'

# %%
print(l1)
# Out:
# ['Badri', 'Vallur', 'dinesh', 'Ram', 'Veer', 'varun']

# %%
for deleting there are two approaches:
1.temporary deleting: creates a carbon copy of the deleted item====>pop()
2.permanent deleting:====> remove()

# %%
p=l1.pop()
print(p)
# Out:
# varun

# %%
print(l1)
# Out:
# ['Badri', 'Vallur', 'Veer']

# %%
d=l1.remove('Ram')
print(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 d=l1.remove('Ram')
#       2 print(d)
#
# ValueError: list.remove(x): x not in list

# %%
b=l1.pop(2)

# %%
print(b)
print(l1)
# Out:
# dinesh
# ['Badri', 'Vallur', 'Veer']

# %%
del l1[2]
print(l1)
# Out:
# ['Badri', 'Vallur']

# %%
r=l1.append(p)

# %%
print(r)
# Out:
# None
