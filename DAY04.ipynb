# %%
Lists
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Lists
#
# NameError: name 'Lists' is not defined

# %%
l1=["badri","vallur","divya","Bhavya","Anshul","Taju"]
print(l1)
# Out:
# ['badri', 'vallur', 'divya', 'Bhavya', 'Anshul', 'Taju']

# %%
print(l1[0:4])
# Out:
# ['badri', 'vallur', 'divya', 'Bhavya']

# %%
print(l1[2:])
# Out:
# ['divya', 'Bhavya', 'Anshul', 'Taju']

# %%
print(l1[0:5:2])
# Out:
# ['badri', 'divya', 'Anshul']

# %%
print(len(l1))
# Out:
# 6

# %%
l1.append("Vamshi")
print(l1)
# Out:
# ['badri', 'vallur', 'divya', 'Bhavya', 'Anshul', 'Taju', 'Vamshi', 'Vamshi']

# %%
l1.remove("Vamshi")
print(l1)
# Out:
# ['badri', 'vallur', 'divya', 'Bhavya', 'Anshul', 'Taju', 'Vamshi']

# %%
print(len(l1))
# Out:
# 7

# %%
l1.sort()
print(l1)
# Out:
# ['Anshul', 'Bhavya', 'Taju', 'Vamshi', 'badri', 'divya', 'vallur']

# %%
l1.reverse()
print(l1)
# Out:
# ['vallur', 'divya', 'badri', 'Vamshi', 'Taju', 'Bhavya', 'Anshul']

# %%
tuples===> immutable

# %%
t=(20,30)
print(t)
# Out:
# (20, 30)

# %%
t[0]=(50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 t[0]=(50)
#
# TypeError: 'tuple' object does not support item assignment

# %%
t==(20)
# Out:
# True

# %%
t==(40)
# Out:
# False
