# %%
classification of datatypes:
1. mutable datatypes----> can be edited--->flexible in nature
2.immutable datatypes--->cannot be edited--->fixed in nature

# %%
Intro to string datatype:

# %%
print("badri")
# Out:
# badri

# %%
print("vallur")
# Out:
# vallur

# %%
first_name="badri vallUR"
first_name.title()
# Out:
# 'Badri Vallur'

# %%
first_name.upper()
# Out:
# 'BADRI VALLUR'

# %%
first_name.lower()
# Out:
# 'badri vallur'

# %%
first_name.split(" ")
# Out:
# ['badri', 'vallUR']
