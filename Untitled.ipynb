# %%
continuation with string datatypes
# Out:
#   Cell In[1], line 1
#     continuation with string datatypes
#                  ^
# SyntaxError: invalid syntax

# %%
first_name="badri"

# %%
last_name="Vallur"

# %%
full_name=(f"{first_name} {last_name}")
print(full_name)
# Out:
# badri Vallur

# %%
print(full_name)
# Out:
# badri Vallur

# %%
message=(f"keep up the good work {full_name}")
print(message)
# Out:
# keep up the good work badri Vallur

# %%
Aadding white spaces to strings

# %%
print("favourite_prog_lang:pythonc++cswiftjava")
# Out:
# favourite_prog_lang:pythonc++cswiftjava

# %%
print("favourite_prog_lang:\npython\nc++\nc\nswift\njava")
# Out:
# favourite_prog_lang:
# python
# c++
# c
# swift
# java

# %%
print("favourite_prog_lang:\tpython\tc++\tc\tswift\tjava")
# Out:
# favourite_prog_lang:	python	c++	c	swift	java

# %%
Removing white spaces from the string

# %%
name="  python"

print(name)
# Out:
#   python

# %%
name2="python   "

print(name2)
# Out:
# python

# %%
name.lstrip()
# Out:
# 'python'

# %%
name2.rstrip()
# Out:
# 'python'

# %%
name3="  python  "

name3.strip()
# Out:
# 'python'
